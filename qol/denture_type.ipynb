# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dentures = pd.read_csv('/Users/janoskonig/Downloads/denture_type.csv')

# %%
dentures
# Out:
#    denture_type responsiveness_today_situation
# 0          both                        Átlagos
# 1          both                        Átlagos
# 2          both                   Nagyon rossz
# 3          both                   Nagyon rossz
# 4         upper                          Rossz
# 5         upper                             Jó
# 6          both                          Rossz
# 7          both                        Átlagos
# 8         upper                             Jó
# 9          both                             Jó
# 10         both                             Jó
# 11        lower                          Rossz
# 12         both                   Nagyon rossz
# 13        lower                         Kiváló
# 14        lower                             Jó
# 15        lower                             Jó
# 16         both                             Jó
# 17         both                         Kiváló
# 18        upper                         Kiváló
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       3 sns.set(style="whitegrid")
#       4 plt.figure(figsize=(10, 6))
# ----> 5 sns.violinplot(x="responsiveness_today_situation", y="upper", data=dentures, inner="quartile")
#       6 plt.title("Violin plot of upper dentures by responsiveness today situation")
#       7 plt.xlabel("Responsiveness Today Situation")
#
# File ~/anaconda3/envs/taf/lib/python3.12/site-packages/seaborn/categorical.py:1725, in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1714 def violinplot(
# ...
