# %%
b1 = 0.03*(12/20)
b2 = 0.04*(5/20)
b3 = 0.05*(3/20)

a = b1 + b2 + b3
print("A selejt valószínűsége = ", a)
# Out:
# A selejt valószínűsége =  0.0355

# %%
print("Ha selejtes, mekkora valószínűséggel jön a B1-ből?")
b1_bayes = 0.03*(12/20)/a
print("B1 selejt valószínűsége = ", b1_bayes)
# Out:
# Ha selejtes, mekkora valószínűséggel jön a B1-ből?
# B1 selejt valószínűsége =  0.5070422535211268
